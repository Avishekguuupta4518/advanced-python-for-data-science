# %%
print("Hello Class! I hope you all are doing good!")
# Out:
# Hello Class! I hope you all are doing good!

# %%
# This is a single-line comment

"""This is a
multi-line comment """

print("I will only be printed")
# Out:
# I will only be printed

# %%
is_valid = True # Boolean

X = 5  # Integer

y = 3.14 # Float

name = "John" # String

# %%
# Arithmetic operations

sum = 5 + 3
diff = 5 - 3
prod = 5 * 3
quot = 5 / 3
mod = 5 % 3

# Logical operations
and_op = True and False
or_op = True or False
not_op = not True

# %%
# Arithmetic operations
sum_val = 5 + 3
diff = 5 - 3
prod = 5 * 3
quot = 5 / 3
mod = 5 % 3

print("Sum:", sum_val)        # 8
print("Difference:", diff)    # 2
print("Product:", prod)       # 15
print("Quotient:", quot)      # 1.666...
print("Modulus:", mod)        # 2

# Logical operations
and_op = True and False
or_op = True or False
not_op = not True

print("AND operation:", and_op)   # False
print("OR operation:", or_op)     # True
print("NOT operation:", not_op)   # False
# Out:
# Sum: 8
# Difference: 2
# Product: 15
# Quotient: 1.6666666666666667
# Modulus: 2
# AND operation: False
# OR operation: True
# NOT operation: False

# %%
fruits = ["apple", "banana", "cherry"]
fruits.append("date")
print(fruits)
print(fruits[0])
# Out:
# ['apple', 'banana', 'cherry', 'date']
# apple

# %%
coordinates = (10, 20, 30)
print(coordinates [0])
print(type(coordinates))
# Out:
# 10
# <class 'tuple'>

# %%
unique_numbers = {1, 2, 3, 3}
print(unique_numbers)
unique_numbers.add(4)
print(unique_numbers)
print(type(unique_numbers))
# Out:
# {1, 2, 3}
# {1, 2, 3, 4}
# <class 'set'>

# %%
person = {"name": "John", "age": 30}
print(person["name"])
print(person ["age"])
person ["address" ] = "Dharan"
print(person)
print(type(person))
# Out:
# John
# 30
# {'name': 'John', 'age': 30, 'address': 'Dharan'}
# <class 'dict'>

# %%
email = input("enter your email ")
password = input("enrer your password ")
if email == "hello@hello.com" and password == "hello123":
    print("Logged in!")
else:
    print("Invalid Password")
# Out:
# Logged in!

# %%
yob = int(input("Please enter your Birth Year: "))
age = 2081 - yob
if age >= 18:
    print("You are an adult.")
elif age >= 13:
    print("You are a teenager.")
else:
    print("You are a child.")
# Out:
# You are an adult.

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
count = 0
while count < 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4
