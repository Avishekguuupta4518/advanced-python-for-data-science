# %%
import requests
from pprint import pprint

url = "https://jsonplaceholder.typicode.com/posts/1"

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    pprint(data)
else:
    print("Error:", response.status_code)
# Out:
# {'body': 'quia et suscipit\n'
#          'suscipit recusandae consequuntur expedita et cum\n'
#          'reprehenderit molestiae ut ut quas totam\n'
#          'nostrum rerum est autem sunt rem eveniet architecto',
#  'id': 1,
#  'title': 'sunt aut facere repellat provident occaecati excepturi optio '
#           'reprehenderit',
#  'userId': 1}

# %%
import requests

url = "https://jsonplaceholder.typicode.com/posts"

payload = {"title":"Test", "body":"Hello API", "user_Id": 1}
response = requests.post(url, json=payload)    
print(response.json())
# Out:
# {'title': 'Test', 'body': 'Hello API', 'user_Id': 1, 'id': 101}

# %%
from zeep import Client

wsdl = "http://www.dneonline.com/calculator.asmx?WSDL"

client = Client(wsdl=wsdl)

result = client.service.Add(10, 20)

print(result)
# Out:
# 30

# %%
import requests

api_key = "31454b4282bc69567483ad1dd8d07af2"
city = "Dharan"


response = requests.get(url)
data = response.json()
print(data)
# Out:
# {'coord': {'lon': 87.2835, 'lat': 26.8125}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 20.16, 'feels_like': 19.43, 'temp_min': 20.16, 'temp_max': 20.16, 'pressure': 1017, 'humidity': 46, 'sea_level': 1017, 'grnd_level': 969}, 'visibility': 10000, 'wind': {'speed': 1.33, 'deg': 210, 'gust': 1.02}, 'clouds': {'all': 0}, 'dt': 1768883029, 'sys': {'country': 'NP', 'sunrise': 1768870823, 'sunset': 1768909365}, 'timezone': 20700, 'id': 1283460, 'name': 'Dharān', 'cod': 200}

# %%
import pandas as pd
from pandas import json_normalize

# Flatten nested JSON
df = json_normalize(data)
print(df.head())
# Out:
#                                              weather      base  visibility  \
# 0  [{'id': 800, 'main': 'Clear', 'description': '...  stations       10000
#
#            dt  timezone       id    name  cod  coord.lon  coord.lat  ...  \
# 0  1768883029     20700  1283460  Dharān  200    87.2835    26.8125  ...
#
#    main.humidity  main.sea_level  main.grnd_level  wind.speed  wind.deg  \
# 0             46            1017              969        1.33       210
#
#    wind.gust  clouds.all  sys.country  sys.sunrise  sys.sunset
# 0       1.02           0           NP   1768870823  1768909365
#
# [1 rows x 25 columns]
